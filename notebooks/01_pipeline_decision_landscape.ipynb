# %%
# !pip -q install pandas numpy matplotlib seaborn openpyxl

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

os.makedirs("figures", exist_ok=True)
os.makedirs("outputs", exist_ok=True)

sns.set(style="whitegrid", context="talk")
np.random.seed(42)

# %%
data = [
    ["Motion regression", "preprocessing", 0.92],
    ["Global signal regression", "preprocessing", 0.61],
    ["Bandpass filter", "preprocessing", 0.84],
    ["Atlas choice", "analysis", 0.77],
    ["Thresholding rule", "analysis", 0.58],
    ["Multiple comparison correction", "statistics", 0.81],
    ["Scrubbing criteria", "preprocessing", 0.55],
    ["Connectivity metric", "analysis", 0.73]
]

df = pd.DataFrame(
    data,
    columns=["decision", "stage", "usage_rate"]
)

df
# Out:
#                          decision          stage  usage_rate
# 0               Motion regression  preprocessing        0.92
# 1        Global signal regression  preprocessing        0.61
# 2                 Bandpass filter  preprocessing        0.84
# 3                    Atlas choice       analysis        0.77
# 4               Thresholding rule       analysis        0.58
# 5  Multiple comparison correction     statistics        0.81
# 6              Scrubbing criteria  preprocessing        0.55
# 7             Connectivity metric       analysis        0.73

# %%
summary = (
    df.sort_values("usage_rate", ascending=False)
)

summary
# Out:
#                          decision          stage  usage_rate
# 0               Motion regression  preprocessing        0.92
# 2                 Bandpass filter  preprocessing        0.84
# 5  Multiple comparison correction     statistics        0.81
# 3                    Atlas choice       analysis        0.77
# 7             Connectivity metric       analysis        0.73
# 1        Global signal regression  preprocessing        0.61
# 4               Thresholding rule       analysis        0.58
# 6              Scrubbing criteria  preprocessing        0.55

# %%
plt.figure(figsize=(12,5))

ax = sns.barplot(
    data=summary,
    x="decision",
    y="usage_rate",
    hue="stage"
)

plt.xticks(rotation=35, ha="right")
plt.xlabel("")
plt.ylabel("Relative Usage Rate")
plt.title("Pipeline Decision Landscape")

ax.legend(
    title="stage",
    fontsize=10,
    title_fontsize=10,
    markerscale=0.8,
    bbox_to_anchor=(1.02, 1),
    loc="upper left",
    borderaxespad=0
)

plt.tight_layout()
plt.savefig("figures/01_pipeline_landscape.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
df.to_csv("outputs/01_pipeline_decisions.csv", index=False)
summary.to_csv("outputs/01_pipeline_summary.csv", index=False)

summary
# Out:
#                          decision          stage  usage_rate
# 0               Motion regression  preprocessing        0.92
# 2                 Bandpass filter  preprocessing        0.84
# 5  Multiple comparison correction     statistics        0.81
# 3                    Atlas choice       analysis        0.77
# 7             Connectivity metric       analysis        0.73
# 1        Global signal regression  preprocessing        0.61
# 4               Thresholding rule       analysis        0.58
# 6              Scrubbing criteria  preprocessing        0.55
